# %% [markdown]
# Exploration of Toronto's DineSafe data set.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json("./data/dinesafe.json")
df.tail()
# Out:
#          _id  Rec #  Establishment ID  Inspection ID  \
# 46122  46123  46123          10577643            NaN
# 46123  46124  46124          10429136    104975907.0
# 46124  46125  46125          10429136    105035491.0
# 46125  46126  46126          10696752    105055780.0
# 46126  46127  46127          10770910    105092374.0
#
#                         Establishment Name      Establishment Type  \
# 46122                    Zhong Wei Company              Food Depot
# 46123                          iQ FOOD CO.              Restaurant
# 46124                          iQ FOOD CO.              Restaurant
# 46125                                  iQx              Restaurant
# 46126  ÉCOLE SECONDAIRE TORONTO OUEST- SNP  Student Nutrition Site
#
#                 Establishment Address Establishment Status  \
# 46122  200 SILVER STAR BLVD, Unit-312                 Pass
# 46123                      181 BAY ST                 Pass
# ...

# %%
df[~df["Inspection ID"].notnull()]
# Out:
#          _id  Rec #  Establishment ID  Inspection ID  \
# 54        55     55          10431055            NaN
# 58        59     59          10417459            NaN
# 74        75     75          10566372            NaN
# 98        99     99          10464953            NaN
# 167      168    168          10541993            NaN
# ...      ...    ...               ...            ...
# 45692  45693  45693          10587723            NaN
# 45696  45697  45697          10252386            NaN
# 46005  46006  46006          10186651            NaN
# 46014  46015  46015          10601017            NaN
# 46122  46123  46123          10577643            NaN
#
#                      Establishment Name                Establishment Type  \
# 54        112-GARRISON CREEK FLAT GRILL                      Hot Dog Cart
# 58            117-CORKTOWN FRESH BURGER                     Food Take Out
# 74        132-OLD SPADINA AVENUE KOSHER                     Food Take Out
# ...
